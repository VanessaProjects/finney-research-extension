# %%
data = {
    "firm": ["Cantor", "Simon", "Goldblatt + Singer", "Finney"],
    "archetype": ["Volume", "Premium", "Boutique", "Boutique"]
}
df = pd.DataFrame(data)
print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       1 data = {
#       2     "firm": ["Cantor", "Simon", "Goldblatt + Singer", "Finney"],
#       3     "archetype": ["Volume", "Premium", "Boutique", "Boutique"]
#       4 }
# ----> 5 df = pd.DataFrame(data)
#       6 print(df)
#       7
#
# NameError: name 'pd' is not defined

# %%
pythonimport pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("Pandas version:", pd.__version__)
print("NumPy version:", np.__version__)
print("Setup successful!")

data = {
    "firm": ["Cantor", "Simon", "Goldblatt + Singer", "Finney"],
    "archetype": ["Volume", "Premium", "Boutique", "Boutique"]
}
df = pd.DataFrame(data)
print(df)
# Out:
#   Cell In[2], line 1
#     pythonimport pandas as pd
#                  ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import numpy as np

print("Pandas version:", pd.__version__)
print("Setup successful!")

data = {"firm": ["Cantor", "Simon", "Finney"], "archetype": ["Volume", "Premium", "Boutique"]}
df = pd.DataFrame(data)
print(df)
# Out:
# Pandas version: 3.0.3
# Setup successful!
#      firm archetype
# 0  Cantor    Volume
# 1   Simon   Premium
# 2  Finney  Boutique
